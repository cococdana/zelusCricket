# %%
import cricketstats
import pandas as pd
import numpy as np
import requests
from pandas.core.frame import DataFrame
import json
import csv
import os
import glob
import pprint
import requests, zipfile
from io import BytesIO
from urllib.request import urlopen
import warnings
warnings.filterwarnings("ignore")

# %%
endpoint ="https://cricsheet.org/downloads/odis_json.zip"
response = requests.get(endpoint)
html = urlopen(endpoint).read()

# %%
r = requests.get("https://cricsheet.org/downloads/odis_json.zip", stream=True)
z = zipfile.ZipFile(BytesIO(r.content))
z.extractall()
type(z)
# Out:
# zipfile.ZipFile

# %%
#unzip json file
from zipfile import ZipFile
  
# loading the temp.zip and creating a zip object
with ZipFile(z, 'r') as zObject:
    for file_name in file_names:
        with open(file_name) as f:
            file_data = json.load(f)  # load data from JSON to dict
            for k, v in file_data.items():  # iterate over key-value pairs
                collection.insert_one(v)  # your collection object here
            zObject.extractall(
        path="odis/jsons")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 5
#       2 from zipfile import ZipFile
#       4 # loading the temp.zip and creating a zip object
# ----> 5 with ZipFile(z, 'r') as zObject:
#       6
#       7     # Extracting all the members of the zip
#       8     # into a specific location.
#       9     zObject.extractall(
#      10         path="odis/jsons")
#
# File /usr/local/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/zipfile.py:1301, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1299 try:
#    1300     if mode == 'r':
# -> 1301         self._RealGetContents()
#    1302     elif mode in ('w', 'x'):
#    1303         # set the modified flag so central directory gets written
#    1304         # even if no files are added to the archive
#    1305         self._didModify = True
#
# File /usr/local/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/zipfile.py:1364, in ZipFile._RealGetContents(self)
#    1362 fp = self.fp
#    1363 try:
# -> 1364     endrec = _EndRecData(fp)
#    1365 except OSError:
#    1366     raise BadZipFile("File is not a zip file")
#
# File /usr/local/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/zipfile.py:292, in _EndRecData(fpin)
#     286 """Return data from the "End of Central Directory" record, or None.
#     287
#     288 The data is a list of the nine items in the ZIP "End of central dir"
#     289 record followed by a tenth item, the file seek offset of this record."""
#     291 # Determine file size
# --> 292 fpin.seek(0, 2)
#     293 filesize = fpin.tell()
#     295 # Check to see if this is ZIP file with no archive comment (the
#     296 # "end of central directory" structure should be the last item in the
#     297 # file if this is the case).
#
# AttributeError: 'ZipFile' object has no attribute 'seek'

# %%
#loop through jsons
directory = os.fsencode(r'odis')
conn = sqlite3.connect('cricketDB.db')    
for file in os.listdir(directory):
     filename = os.fsdecode(file)
     if filename.endswith(".json"): 
        with open("/Users/catherinedana/Zelus/odis/"+filename, 'r') as json_file:
            data = json.load(json_file)
            cat data | jq -r '.data | map([.field1, .field2, .field3] | @csv)| join("\n")' > file.csv
 #       for item in data:  
  #          conn.execute("""\
   #         CREATE TABLE (x BLOB(50))")
    #        conn.execute("INSERT INTO test VALUES (?)", ((item,)))
        
        continue
     else:
        continue

# %%
import os

dir_loc = os.getcwd()
list_of_dir = os.listdir(dir_loc)


for file in list_of_dir:
    with open(file, 'rb') as f:
        temp_file = f.read()
    # Do somethin with the file, it's currently stored in a variable
    print(temp_file) # I used print

# %%
keywordList = []
path = '/Users/catherinedana/Zelus/odis'
for filename in glob.glob(os.path.join(path, '*.json')): #only process .JSON files in folder.      
    with open(filename, encoding='utf-8', mode='r') as currentFile:
        data=currentFile.read().replace('\n', '')
        keyword = json.loads(data)
keyword
# Out:
# {'meta': {'data_version': '1.0.0', 'created': '2012-07-08', 'revision': 3},
#  'info': {'balls_per_over': 6,
#   'city': 'Dunedin',
#   'dates': ['2012-02-03'],
#   'event': {'match_number': 1, 'name': 'Zimbabwe in New Zealand ODI Series'},
#   'gender': 'male',
#   'match_type': 'ODI',
#   'match_type_number': 3230,
#   'officials': {'match_referees': ['DC Boon'],
#    'reserve_umpires': ['GAV Baxter'],
#    'tv_umpires': ['RJ Tucker'],
#    'umpires': ['Enamul Haque', 'CB Gaffaney']},
#   'outcome': {'by': {'runs': 90}, 'winner': 'New Zealand'},
#   'overs': 50,
#   'player_of_match': ['MJ Guptill'],
#   'players': {'New Zealand': ['RJ Nicol',
#     'MJ Guptill',
#     'BB McCullum',
#     'KS Williamson',
#     'TWM Latham',
#     'DG Brownlie',
#     'NL McCullum',
#     'AM Ellis',
#     'DAJ Bracewell',
#     'KD Mills',
#     'TG Southee'],
#    'Zimbabwe': ['H Masakadza',
#     'S Matsikenyeri',
#     'RW Chakabva',
#     'BRM Taylor',
#     'T Taibu',
#     'MN Waller',
#     'E Chigumbura',
#     'KO Meth',
#     'SW Masakadza',
#     'RW Price',
#     'KM Jarvis']},
#   'registry': {'people': {'AM Ellis': 'f987245c',
#     'BB McCullum': 'b8a55852',
#     'BRM Taylor': '53597be1',
#     'CB Gaffaney': 'd5ac41d8',
#     'DAJ Bracewell': '2e9fdf9b',
#     'DC Boon': 'e79a1fe3',
#     'DG Brownlie': '22bd731a',
#     'E Chigumbura': 'd2babdd5',
#     'Enamul Haque': '2ae9be7f',
#     'GAV Baxter': 'cb4b3ab0',
#     'H Masakadza': '31fbf891',
#     'KD Mills': '7fb32e5b',
#     'KM Jarvis': '59792462',
#     'KO Meth': '9fbc7bc4',
#     'KS Williamson': 'd027ba9f',
#     'MJ Guptill': '2be41edb',
#     'MN Waller': 'ec4dada1',
#     'NL McCullum': '5673a3fc',
#     'RJ Nicol': '8d8c24fd',
#     'RJ Tucker': '38810cfc',
#     'RW Chakabva': '2f0d7e4a',
#     'RW Price': '67af6f81',
#     'S Matsikenyeri': 'e7ba1233',
#     'SW Masakadza': '2182013e',
#     'T Taibu': '75de770f',
#     'TG Southee': '13c35c9e',
#     'TWM Latham': 'e824e6ee'}},
#   'season': '2011/12',
#   'team_type': 'international',
#   'teams': ['New Zealand', 'Zimbabwe'],
#   'toss': {'decision': 'field', 'winner': 'Zimbabwe'},
#   'venue': 'University Oval'},
#  'innings': [{'team': 'New Zealand',
#    'overs': [{'over': 0,
#      'deliveries': [{'batter': 'RJ Nicol',
#        'bowler': 'KO Meth',
#        'extras': {'wides': 1},
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'RJ Nicol',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RJ Nicol',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RJ Nicol',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RJ Nicol',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RJ Nicol',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'RJ Nicol',
#          'fielders': [{'name': 'BRM Taylor'}]}]},
#       {'batter': 'BB McCullum',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 3, 'extras': 0, 'total': 3}}]},
#     {'over': 1,
#      'deliveries': [{'batter': 'BB McCullum',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'BB McCullum',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'review': {'by': 'New Zealand',
#         'umpire': 'CB Gaffaney',
#         'batter': 'BB McCullum',
#         'decision': 'struck down'},
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'lbw', 'player_out': 'BB McCullum'}]},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 2,
#      'deliveries': [{'batter': 'KS Williamson',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 3,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 3, 'extras': 0, 'total': 3}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 4,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'extras': {'wides': 1},
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 5,
#      'deliveries': [{'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 6,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'extras': {'wides': 1},
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 7,
#      'deliveries': [{'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 8,
#      'deliveries': [{'batter': 'KS Williamson',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KO Meth',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KO Meth',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 9,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'extras': {'legbyes': 1},
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 10,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'extras': {'wides': 1},
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 11,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'KS Williamson',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 12,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'extras': {'legbyes': 1},
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 13,
#      'deliveries': [{'batter': 'KS Williamson',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'KS Williamson',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'KS Williamson',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 14,
#      'deliveries': [{'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'extras': {'legbyes': 1},
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 15,
#      'deliveries': [{'batter': 'KS Williamson',
#        'bowler': 'RW Price',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'KS Williamson',
#        'bowler': 'RW Price',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'RW Price',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'RW Price',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'RW Price',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'KS Williamson',
#        'bowler': 'RW Price',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 16,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'KS Williamson',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KS Williamson',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught and bowled',
#          'player_out': 'KS Williamson'}]},
#       {'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 17,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 18,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 19,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 20,
#      'deliveries': [{'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'extras': {'wides': 1},
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 21,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 4, 'extras': 0, 'non_boundary': True, 'total': 4}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 22,
#      'deliveries': [{'batter': 'TWM Latham',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TWM Latham',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#     {'over': 23,
#      'deliveries': [{'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 24,
#      'deliveries': [{'batter': 'MJ Guptill',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TWM Latham',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'MJ Guptill',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MJ Guptill',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'bowled', 'player_out': 'MJ Guptill'}]},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 25,
#      'deliveries': [{'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 26,
#      'deliveries': [{'batter': 'TWM Latham',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 27,
#      'deliveries': [{'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'RW Price',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TWM Latham',
#        'bowler': 'RW Price',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 28,
#      'deliveries': [{'batter': 'TWM Latham',
#        'bowler': 'E Chigumbura',
#        'extras': {'legbyes': 1},
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'TWM Latham',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'TWM Latham',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'TWM Latham',
#          'fielders': [{'name': 'T Taibu'}]}]}]},
#     {'over': 29,
#      'deliveries': [{'batter': 'DG Brownlie',
#        'bowler': 'RW Price',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'RW Price',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'RW Price',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'RW Price',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'RW Price',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'RW Price',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 30,
#      'deliveries': [{'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 31,
#      'deliveries': [{'batter': 'DG Brownlie',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 32,
#      'deliveries': [{'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DG Brownlie',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 33,
#      'deliveries': [{'batter': 'NL McCullum',
#        'bowler': 'H Masakadza',
#        'non_striker': 'DG Brownlie',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'run out',
#          'player_out': 'DG Brownlie',
#          'fielders': [{'name': 'RW Chakabva'}]}]},
#       {'batter': 'AM Ellis',
#        'bowler': 'H Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'H Masakadza',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'H Masakadza',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'H Masakadza',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'H Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 34,
#      'deliveries': [{'batter': 'AM Ellis',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 35,
#      'deliveries': [{'batter': 'AM Ellis',
#        'bowler': 'H Masakadza',
#        'extras': {'wides': 1},
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'H Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'H Masakadza',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'H Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'H Masakadza',
#        'extras': {'wides': 1},
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'H Masakadza',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'H Masakadza',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'H Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 36,
#      'deliveries': [{'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}}]},
#     {'over': 37,
#      'deliveries': [{'batter': 'AM Ellis',
#        'bowler': 'KO Meth',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'AM Ellis',
#        'bowler': 'KO Meth',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'KO Meth',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'KO Meth',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'KO Meth',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'AM Ellis',
#        'bowler': 'KO Meth',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 38,
#      'deliveries': [{'batter': 'AM Ellis',
#        'bowler': 'RW Price',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'AM Ellis',
#        'bowler': 'RW Price',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'AM Ellis',
#        'bowler': 'RW Price',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'AM Ellis',
#        'bowler': 'RW Price',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'AM Ellis',
#        'bowler': 'RW Price',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'RW Price',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 39,
#      'deliveries': [{'batter': 'AM Ellis',
#        'bowler': 'KO Meth',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'KO Meth',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'KO Meth',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'KO Meth',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'AM Ellis',
#        'bowler': 'KO Meth',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'AM Ellis',
#        'bowler': 'KO Meth',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 40,
#      'deliveries': [{'batter': 'AM Ellis',
#        'bowler': 'RW Price',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'RW Price',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'RW Price',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'RW Price',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'NL McCullum',
#        'bowler': 'RW Price',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'RW Price',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 41,
#      'deliveries': [{'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'AM Ellis',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'NL McCullum',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'E Chigumbura',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 42,
#      'deliveries': [{'batter': 'AM Ellis',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'AM Ellis',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'AM Ellis',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'AM Ellis',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'bowled', 'player_out': 'AM Ellis'}]},
#       {'batter': 'DAJ Bracewell',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DAJ Bracewell',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 43,
#      'deliveries': [{'batter': 'NL McCullum',
#        'bowler': 'H Masakadza',
#        'non_striker': 'DAJ Bracewell',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DAJ Bracewell',
#        'bowler': 'H Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DAJ Bracewell',
#        'bowler': 'H Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'H Masakadza',
#        'non_striker': 'DAJ Bracewell',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'DAJ Bracewell',
#        'bowler': 'H Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DAJ Bracewell',
#        'bowler': 'H Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 44,
#      'deliveries': [{'batter': 'DAJ Bracewell',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'NL McCullum',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'NL McCullum',
#        'bowler': 'SW Masakadza',
#        'extras': {'legbyes': 2},
#        'non_striker': 'DAJ Bracewell',
#        'runs': {'batter': 0, 'extras': 2, 'total': 2}},
#       {'batter': 'NL McCullum',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'DAJ Bracewell',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'bowled', 'player_out': 'NL McCullum'}]},
#       {'batter': 'KD Mills',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'DAJ Bracewell',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KD Mills',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'DAJ Bracewell',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KD Mills',
#        'bowler': 'SW Masakadza',
#        'non_striker': 'DAJ Bracewell',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 45,
#      'deliveries': [{'batter': 'DAJ Bracewell',
#        'bowler': 'KM Jarvis',
#        'non_striker': 'KD Mills',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'DAJ Bracewell',
# ...
#        'runs': {'batter': 6, 'extras': 0, 'total': 6}},
#       {'batter': 'BRM Taylor',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'MN Waller',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'BRM Taylor',
#          'fielders': [{'name': 'AM Ellis'}]}]},
#       {'batter': 'MN Waller',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'E Chigumbura',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'MN Waller',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'MN Waller',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 26,
#      'deliveries': [{'batter': 'E Chigumbura',
#        'bowler': 'NL McCullum',
#        'non_striker': 'MN Waller',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MN Waller',
#        'bowler': 'NL McCullum',
#        'non_striker': 'E Chigumbura',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'NL McCullum',
#        'non_striker': 'MN Waller',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MN Waller',
#        'bowler': 'NL McCullum',
#        'non_striker': 'E Chigumbura',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'NL McCullum',
#        'non_striker': 'MN Waller',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MN Waller',
#        'bowler': 'NL McCullum',
#        'non_striker': 'E Chigumbura',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 27,
#      'deliveries': [{'batter': 'E Chigumbura',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'MN Waller',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MN Waller',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'E Chigumbura',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'RJ Nicol',
#        'extras': {'wides': 1},
#        'non_striker': 'MN Waller',
#        'runs': {'batter': 0, 'extras': 1, 'total': 1}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'MN Waller',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MN Waller',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'E Chigumbura',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'MN Waller',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'MN Waller',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'E Chigumbura',
#        'review': {'by': 'New Zealand',
#         'umpire': 'CB Gaffaney',
#         'batter': 'MN Waller',
#         'decision': 'upheld'},
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'lbw', 'player_out': 'MN Waller'}]}]},
#     {'over': 28,
#      'deliveries': [{'batter': 'E Chigumbura',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 29,
#      'deliveries': [{'batter': 'KO Meth',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'E Chigumbura',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'E Chigumbura',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'E Chigumbura',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught and bowled',
#          'player_out': 'E Chigumbura'}]},
#       {'batter': 'SW Masakadza',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KO Meth',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'SW Masakadza',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 30,
#      'deliveries': [{'batter': 'SW Masakadza',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KO Meth',
#        'bowler': 'KD Mills',
#        'non_striker': 'SW Masakadza',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'SW Masakadza',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'SW Masakadza',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'SW Masakadza',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'caught',
#          'player_out': 'SW Masakadza',
#          'fielders': [{'name': 'RJ Nicol'}]}]},
#       {'batter': 'RW Price',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 31,
#      'deliveries': [{'batter': 'KO Meth',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'DAJ Bracewell',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}}]},
#     {'over': 32,
#      'deliveries': [{'batter': 'RW Price',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'RW Price',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'RW Price',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'KD Mills',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 33,
#      'deliveries': [{'batter': 'RW Price',
#        'bowler': 'AM Ellis',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'AM Ellis',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'AM Ellis',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'AM Ellis',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'AM Ellis',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KO Meth',
#        'bowler': 'AM Ellis',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}}]},
#     {'over': 34,
#      'deliveries': [{'batter': 'KO Meth',
#        'bowler': 'NL McCullum',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 35,
#      'deliveries': [{'batter': 'KO Meth',
#        'bowler': 'AM Ellis',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'AM Ellis',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'RW Price',
#        'bowler': 'AM Ellis',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'RW Price',
#        'bowler': 'AM Ellis',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'AM Ellis',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 2, 'extras': 0, 'total': 2}},
#       {'batter': 'RW Price',
#        'bowler': 'AM Ellis',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 36,
#      'deliveries': [{'batter': 'KO Meth',
#        'bowler': 'NL McCullum',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'NL McCullum',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'NL McCullum',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'NL McCullum',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 37,
#      'deliveries': [{'batter': 'KO Meth',
#        'bowler': 'AM Ellis',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'AM Ellis',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'AM Ellis',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'AM Ellis',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'AM Ellis',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KO Meth',
#        'bowler': 'AM Ellis',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 38,
#      'deliveries': [{'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 4, 'extras': 0, 'total': 4}},
#       {'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'NL McCullum',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KO Meth',
#        'bowler': 'NL McCullum',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 39,
#      'deliveries': [{'batter': 'RW Price',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'KO Meth',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'KO Meth',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'lbw', 'player_out': 'KO Meth'}]},
#       {'batter': 'KM Jarvis',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KM Jarvis',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'KM Jarvis',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'RW Price',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'KM Jarvis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 40,
#      'deliveries': [{'batter': 'KM Jarvis',
#        'bowler': 'TG Southee',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 1, 'extras': 0, 'total': 1}},
#       {'batter': 'RW Price',
#        'bowler': 'TG Southee',
#        'non_striker': 'KM Jarvis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'TG Southee',
#        'non_striker': 'KM Jarvis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'TG Southee',
#        'non_striker': 'KM Jarvis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'TG Southee',
#        'non_striker': 'KM Jarvis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}},
#       {'batter': 'RW Price',
#        'bowler': 'TG Southee',
#        'non_striker': 'KM Jarvis',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0}}]},
#     {'over': 41,
#      'deliveries': [{'batter': 'KM Jarvis',
#        'bowler': 'RJ Nicol',
#        'non_striker': 'RW Price',
#        'runs': {'batter': 0, 'extras': 0, 'total': 0},
#        'wickets': [{'kind': 'stumped',
#          'player_out': 'KM Jarvis',
#          'fielders': [{'name': 'BB McCullum'}]}]}]}],
#    'powerplays': [{'from': 0.1, 'to': 9.6, 'type': 'mandatory'},
#     {'from': 15.1, 'to': 19.6, 'type': 'fielding'},
#     {'from': 35.1, 'to': 39.6, 'type': 'batting'}],
#    'target': {'overs': 50, 'runs': 249}}]}

# %%
type(keyword)
# Out:
# dict

# %%
#requests.get('https://cricsheet.org/downloads/odis_json.zip').json()

# %%
#Read file and print a line
webFD=urllib2.urlopen("https://cricsheet.org/downloads/odis_json.zip")
tweet = webFD.readline()
tweet


#create dictionary
dictt=json.loads(tweet)

#print dictionary
dictt.keys()

#print values
dictt.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 #Read file and print a line
# ----> 2 webFD=urllib2.urlopen("https://cricsheet.org/downloads/odis_json.zip")
#       3 tweet = webFD.readline()
#       4 tweet
#
# NameError: name 'urllib2' is not defined
